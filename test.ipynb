# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from dataloader import parse_off

# %%
off_path = 'ModelNet10/bathtub/test'
off_files = os.listdir(off_path)
off_file_path = os.path.join(off_path, off_files[5])
print(off_file_path)
# Out:
# ModelNet10/bathtub/test/bathtub_0138.off

# %%
pcd_points = parse_off(off_file_path)
print(np.array(pcd_points).shape)
pcd_points[0]
# Out:
# (847750, 3)
# [48.418, 85.35325, 22.63305]

# %%
X = [p[0] for p in pcd_points]
Y = [p[1] for p in pcd_points]
Z = [p[2] for p in pcd_points]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X, Y, Z, c='r')
plt.show()

# %%
from utils import *
from dataloader import *

# %%
v1 = np.array([0,0])
v2 = np.array([2,2])
v3 = np.array([4,0])

pts = triangle_sampling(v1,v2,v3,100)

# %%
pts[0]
# Out:
# array([1.52713966, 0.95634768])

# %%
plt.scatter([0],[0],c='b')
plt.scatter([2],[2],c='b')
plt.scatter([4],[0],c='b')
plt.scatter(pts[:,0], pts[:,1], c='r')

plt.show()

# %%
from utils import *
from visualise import visualisePCD
from dataloader import *

# %%
data_dir = 'ModelNet10'
train_loader = getDataloader(data_dir=data_dir, split='train')
test_loader = getDataloader(data_dir=data_dir, split='test')

# %%
for batch, mask in train_loader:
    # print(batch.shape)
    # print(mask.shape)
    print(batch[0][mask[0].bool()].shape)
    break
# Out:
# torch.Size([23452312, 3])
