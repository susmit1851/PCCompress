# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from dataloader import parse_off

# %%
off_path = 'ModelNet10/bathtub/test'
off_files = os.listdir(off_path)
off_file_path = os.path.join(off_path, off_files[5])
print(off_file_path)
# Out:
# ModelNet10/bathtub/test/bathtub_0138.off

# %%
pcd_points = parse_off(off_file_path)
print(np.array(pcd_points).shape)
pcd_points[0]
# Out:
# (847750, 3)
# [48.418, 85.35325, 22.63305]

# %%
X = [p[0] for p in pcd_points]
Y = [p[1] for p in pcd_points]
Z = [p[2] for p in pcd_points]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X, Y, Z, c='r')
plt.show()

# %%
from utils import *
from dataloader import *

# %%
v1 = np.array([0,0])
v2 = np.array([2,2])
v3 = np.array([4,0])

pts = triangle_sampling(v1,v2,v3,100)

# %%
pts[0]
# Out:
# array([2.36571218, 1.53076054])

# %%
plt.scatter([0],[0],c='b')
plt.scatter([2],[2],c='b')
plt.scatter([4],[0],c='b')
plt.scatter(pts[:,0], pts[:,1], c='r')

plt.show()

# %%
from utils import *
from visualise import visualisePCD
from dataloader import *

# %%
data_dir = 'ModelNet10'
train_loader = getDataloader(data_dir=data_dir, split='train')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 data_dir = 'ModelNet10'
# ----> 2 train_loader = getDataloader(data_dir=data_dir, split='train')
#
# File ~/Downloads/archive/dataloader.py:164, in getDataloader(data_dir, split, batch_size, num_pts_triangle, shuffle, num_workers)
#     163 def getDataloader(data_dir, split, batch_size=8, num_pts_triangle=500, shuffle=True, num_workers=4):
# --> 164     dataset = PCDataset(data_dir=data_dir, split=split, num_pts_triangle=num_pts_triangle)
#     165     return DataLoader(
#     166         dataset=dataset,
#     167         batch_size=batch_size,
#    (...)
#     171         pin_memory=True
#     172     )
#
# File ~/Downloads/archive/dataloader.py:155, in PCDataset.__init__(self, data_dir, split, num_pts_triangle)
#     153 # Process files in parallel
#     154 with concurrent.futures.ThreadPoolExecutor() as executor:
# --> 155     self.data = list(executor.map(process_file, file_paths))
#
# File ~/anaconda3/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/anaconda3/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/anaconda3/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/anaconda3/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
